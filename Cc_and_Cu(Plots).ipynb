# %% [markdown]
# <a href="https://colab.research.google.com/github/Bala534/Regproject/blob/main/Cc_and_Cu(Plots).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
data = pd.read_excel('Cu and Cu Table of Data.xlsx')
data.head()
# Out:
#    S NO  HC (%)  NQF (%)  C (%)  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0     1     0.0     0.00  23.02        2.00       15.00        0.84        2.05
# 1     2     0.1     0.01  23.02        1.98       15.01        0.85        2.05
# 2     3     0.2     0.02  23.03        1.96       15.04        0.86        2.06
# 3     4     0.3     0.03  23.03        1.96       15.09        0.87        2.06
# 4     5     0.4     0.04  23.04        1.93       15.14        0.88        2.06

# %%
data.rename(columns = {'Unnamed: 4':'Ac','Unnamed: 5':'Φ','Unnamed: 6':'Cc','Unnamed: 7':'Cu'}, inplace = True) # Changing the column names

# %%
del data['S NO']

# %%
data.shape
# Out:
# (121, 7)

# %%
sns.pairplot(data,vars=['HC (%)','NQF (%)','C (%)','Ac','Φ','Cc'])

# %%
sns.pairplot(data,vars=['HC (%)','NQF (%)','C (%)','Ac','Φ','Cu'])

# %%
x = np.array(['MAE','MSE','RMSE','R2_error'])
y = np.array([0.0384,0.0062,0.9975,0.9951])

# %%
plt.bar(x,y,color='g')
plt.xlabel('Performance measure')
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')
